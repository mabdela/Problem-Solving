# %%
'''
692. Top K Frequent Words
Given a non-empty list of words, return the k most frequent elements.

Your answer should be sorted by frequency from highest to lowest. 
If two words have the same frequency, then the word with the lower alphabetical order comes first.

Example 1:
Input: ["i", "love", "leetcode", "i", "love", "coding"], k = 2
Output: ["i", "love"]
Explanation: "i" and "love" are the two most frequent words.
    Note that "i" comes before "love" due to a lower alphabetical order.
Example 2:
Input: ["the", "day", "is", "sunny", "the", "the", "the", "sunny", "is", "is"], k = 4
Output: ["the", "is", "sunny", "day"]
Explanation: "the", "is", "sunny" and "day" are the four most frequent words,
    with the number of occurrence being 4, 3, 2 and 1 respectively.
Note:
You may assume k is always valid, 1 ≤ k ≤ number of unique elements.
Input words contain only lowercase letters.
Follow up:
Try to solve it in O(n log k) time and O(n) extra space.
'''
class Solution:
    def topKFrequent(self, words, k):
        
        data ={}
        
        for i in words: 
            if i not in data.keys():
                data[i] = 1
            else:
                data[i]+=1
        
            
        s = sorted(data.items(), key=lambda item:item[0])
        
        data = {x:v for x, v in sorted(s, key=lambda item:item[1], reverse=True)}
        
        # can replace the above two lines with the following as well
        #data = {x:v for x, v in sorted(data.items(), lambda item:(-item[1], item[0]))}
        
        # or we can save the result in a list as follows
        # ans = sorted(data.keys(), key=lambda item: (-data[item], item))
        # and return ans[0:k]
           
                
        return list(data.keys())[0:k]
    
    # Method 2 using collections and heapq
    
    '''
    
from heapq import nsmallest
from collections import Counter

class Solution:
    def topKFrequent(self, words: List[str], k: int) -> List[str]:
        freq = Counter(words)
        return nsmallest(k, freq.keys(), key=lambda x: (-freq[x], x))
    
    '''

# %% [markdown]
# ---

# %%
"""
Convert Integers between 1 to 3999 into Roman Numbers.
"""

class Solution:
    
    def ansPartial(self, num):
        
        arr = [1000, 900, 500, 400, 100, 90, 50, 40, 10, 9, 5, 4, 1]
        lookup = {1:"I", 4:"IV", 5:"V", 9:"IX", 10:"X", 40:"XL", 50:"L",\
                 90:"XC", 100:"C", 400:"CD", 500:"D", 900:"CM", 1000:"M"}
        for i in arr:
            if(num/i >=1):
                return i, lookup[i]
        
    
    
    def intToRoman(self, num: int) -> str:

        
        result = ""
        
        num_copy = num
        reminder =0
        
        while(num_copy>0):
            temp, temp2 = self.ansPartial(num_copy)
            result+temp2
            num_copy = num_copy-temp
            
        return result
    
    #Method 2
    """
    class Solution:
     
    def intToRoman(self, num: int) -> str:
        d = {3000:"MMM",2000:"MM", 1000: "M",900: "CM", 500: "D", 400: "CD", 100: "C", 200: "CC", \
             300: "CCC", 600: "DC", 700: "DCC", 800: "DCCC", 90: "XC", 50: "L",\
             40: "XL", 10: "X", 20: "XX", 30: "XXX",  60: "LX", 70: "LXX", 80: "LXXX",\
             9: "IX", 5: "V", 4: "IV", 1: "I", 2: "II", 3: "III",6: "VI", 7: "VII", 8: "VIII",  0: ""}
        
        return d[(num // 1000) * 1000] + d[((num % 1000)//100)*100] + d[((num % 100)//10)*10] + d[(num % 10)]
    
    """

# %% [markdown]
# ---

# %%
"""
The finction given below converts Roman number into integer. 
"""
class Solution:
    def romanToInt(self, s: str) -> int:
        lookup = {"I":1, "IV":4, "V":5, "IX":9, "X":10, "XL":40, "L":50,\
                  "XC":90, "C":100, "CD":400, "D":500, "CM":900, "M":1000}
        
        s_copy = s
        result =0
        
        while(len(s_copy)):
            if(s_copy[0]=='I'):
                if('IV' in s_copy):
                    result+=lookup['IV']
                    s_copy=s_copy[2:]
                elif('IX' in s_copy):
                    result+=lookup['IX']
                    s_copy = s_copy[2:]
                else:
                    result+=lookup['I']
                    s_copy = s_copy[1:]
            elif(s_copy[0]=='X'):
                if('XL' in s_copy):
                    result+=lookup['XL']
                    s_copy = s_copy[2:]
                elif('XC' in s_copy):
                    result+=lookup['XC']
                    s_copy = s_copy[2:]
                else:
                    result+=lookup['X']
                    s_copy = s_copy[1:]
            elif(s_copy[0]=='C'):
                if('CD' in s_copy):
                    result+=lookup['CD']
                    s_copy = s_copy[2:]
                elif('CM' in s_copy):
                    result+=lookup['CM']
                    s_copy = s_copy[2:]
                else:
                    result+=lookup['C']
                    s_copy = s_copy[1:]
            else:
                result+=lookup[s_copy[0]]
                s_copy = s_copy[1:]
                
        return result

# %% [markdown]
#  ---
