# %%
"""
Remove the Nth Node form the end of a list.
"""
# Definition for singly-linked list.
class ListNode(object):
    def __init__(self, x):
        self.val = x
        self.next = None

class Solution(object):
    def removeNthFromEnd(self, head, n):
        """
        :type head: ListNode
        :type n: int
        :rtype: ListNode
        """
        fast = head
        slow = head
        
        for i in range(n):
            fast = fast.next
        
        if(fast==None):
            head = head.next
            return head
        
        while(fast.next!=None):
            fast = fast.next
            slow = slow.next
        
        slow.next = slow.next.next
        
        return head

# %%
"""
Merge Two Sorted Linked-Lists (Note the array case is different)
"""

# Definition for singly-linked list.
class ListNode:
    def __init__(self, x):
        self.val = x
        self.next = None

class Solution:
    def mergeTwoLists(self, l1: ListNode, l2: ListNode) -> ListNode:
        
        if(l1==None):
            return l2
        if(l2==None):
            return l1
        
        if(l2.val<l1.val):
            result = l2
            result.next = self.mergeTwoLists(l1, l2.next)
        else:
            result = l1
            result.next = self.mergeTwoLists(l1.next, l2)
        
        return result

# %%
"""
Merge k Sorted Lists
"""

# Definition for singly-linked list.
class ListNode:
    def __init__(self, x):
        self.val = x
        self.next = None

class Solution:
    def mergeTwoLists(self, l1: ListNode, l2: ListNode) -> ListNode:
        
        if(l1==None):
            return l2
        if(l2==None):
            return l1
        
        if(l2.val<l1.val):
            result = l2
            result.next = self.mergeTwoLists(l1, l2.next)
        else:
            result = l1
            result.next = self.mergeTwoLists(l1.next, l2)
        
        return result
    
    def mergeKLists(self, lists):
        
        if(len(lists)<1):
            return None
        
        head = lists[0]
        start = lists[1:]
        
        for item in start:
            head = self.mergeTwoLists(head, item)
        
        return head

# %%
"""
Swap Nodes in Pairs    e.g. Given 1->2->3->4, you should return the list as 2->1->4->3.
"""

# Definition for singly-linked list.
class ListNode:
    def __init__(self, x):
        self.val = x
        self.next = None

class Solution:
    def swapPairs(self, head: ListNode) -> ListNode:
        
        dummy = ListNode(0)
        dummy.next = head
        fast = dummy.next
        slow = dummy;
        
        while(fast!=None and fast.next!=None):
            
            temp =fast.next
            slow.next = fast.next
            fast.next = fast.next.next
            temp.next = fast
            
            slow = fast
            fast = slow.next
        
        return dummy.next

# %%
#Reverse Nodes in k-Group  (Hard---need to be done latter)

#Given this linked list: 1->2->3->4->5, For k = 2, you should return: 2->1->4->3->5
#For k = 3, you should return: 3->2->1->4->5

# Definition for singly-linked list.
# class ListNode:
#     def __init__(self, x):
#         self.val = x
#         self.next = None

class Solution:
    def reverseKGroup(self, head: ListNode, k: int) -> ListNode:
        if not head:
            return
        if not k:
            return
        temp=head
        prev=None
        stack=[]
        while temp:
            count=0
            while temp and count != k:
                stack.append(temp.val)
                temp=temp.next
                count+=1
            if len(stack)<k:
                stack=stack[::-1]
                while stack:
                    if prev == None:
                        prev=ListNode(stack.pop())
                        head=prev
                    else:
                        prev.next=ListNode(stack.pop())
                        prev=prev.next
            else:
                while stack:
                    if prev == None:
                        prev=ListNode(stack.pop())
                        head=prev
                    else:
                        prev.next=ListNode(stack.pop())
                        prev=prev.next
        prev.next=None
        return head

# %% [markdown]
# ---

# %%
'''
23. Merge k Sorted Lists
Merge k sorted linked lists and return it as one sorted list. Analyze and describe its complexity.

Example:

Input:
[
  1->4->5,
  1->3->4,
  2->6
]
Output: 1->1->2->3->4->4->5->6

'''

# Definition for singly-linked list.
class ListNode:
    def __init__(self, x):
        self.val = x
        self.next = None

class Solution:
    def mergeTwoLists(self, l1: ListNode, l2: ListNode) -> ListNode:
        
        if(l1==None):
            return l2
        if(l2==None):
            return l1
        
        if(l2.val<l1.val):
            l2.next = self.mergeTwoLists(l1, l2.next)
            return l2
        else:
            l1.next = self.mergeTwoLists(l1.next, l2)
            return l1
        
    
    def mergeKLists(self, lists) -> ListNode:
        
        if(len(lists)<1):
            return None
        
        head = lists[0]
        
        while len(lists)>1:
            list1 = lists.pop(0)
            list2 = lists.pop(0)
            head = self.mergeTwoLists(list1, list2)
            lists.append(head)
        
        
        return head
    
    # Method 2, faster!
    '''
    import heapq

class Solution:
    def mergeKLists(self, lists: List[ListNode]) -> ListNode:
        heap = []
        for head in lists:
            curr = head 
            while curr:
                heap.append(curr.val)
                curr = curr.next
                
        heapq.heapify(heap)
        
        dummy = ListNode(0)
        cur = dummy
        while heap:
            cur.next = ListNode(heapq.heappop(heap))
            cur = cur.next
            
        return dummy.next
    
    '''

# %% [markdown]
# ---

# %%
'''
114. Flatten Binary Tree to Linked List

Given a binary tree, flatten it to a linked list in-place.

For example, given the following tree:

    1
   / \
  2   5
 / \   \
3   4   6
The flattened tree should look like:

1
 \
  2
   \
    3
     \
      4
       \
        5
         \
          6

'''
# Definition for a binary tree node.
class TreeNode:
     def __init__(self, x):
        self.val = x
        self.left = None
        self.right = None

class Solution:
    def flatten(self, root: TreeNode) -> None:
        """
        Do not return anything, modify root in-place instead.
        """
        
        if(not root):
            return None
        
        result =[]
        
        def helper(root):
            
            if not root:
                return 
            
            result.append(root)
            helper(root.left)
            helper(root.right)

        helper(root)
        root = result.pop(0)
        root.left = None
        while (result):
            root.right = result.pop(0)
            root = root.right
            root.left = None
            
    # Method 2
    '''
     def flatten(self, root: TreeNode) -> None:
        """
        Do not return anything, modify root in-place instead.
        """
        if(not root):
            return

        self.current = None
        
        def helper(root):
            if not root:
                return 
            
            helper(root.right)
            helper(root.left)
            
            
            root.right = self.current
            self.current = root
            root.left = None
        
        helper(root)

    
    
    '''

# %% [markdown]
# ---

# %%
"""
206. Reverse Linked List
Reverse a singly linked list.

Example:

Input: 1->2->3->4->5->NULL
Output: 5->4->3->2->1->NULL
Follow up:

A linked list can be reversed either iteratively or recursively. Could you implement both?

"""
# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next


class Solution:
    def reverseList(self, head: ListNode) -> ListNode:
        
        if not head or not head.next:
            return head
        
        ptr1 = head
        ptr2 = ptr1.next
        ptr1.next = None
        
        while ptr2.next!=None:
            temp = ptr2.next
            ptr2.next = ptr1
            ptr1 = ptr2
            ptr2=temp
            
        ptr2.next = ptr1
        

        return ptr2
    
    #Alternatively, the problem can be solved using stack as shown below.
    """
class Solution:
    def reverseList(self, head: ListNode) -> ListNode:

        if not head:
            return None
        
        stack = [head]
        
        while head.next!=None:
            stack.append(head.next)
            head = head.next
        
        head = temp = stack.pop()
        while stack:
            temp.next = stack.pop()
            temp = temp.next
        temp.next = None
        return head

    """

# %% [markdown]
# ---

# %%
"""
143. Reorder List
Given a singly linked list L: L0→L1→…→Ln-1→Ln,
reorder it to: L0→Ln→L1→Ln-1→L2→Ln-2→…

You may not modify the values in the list's nodes, only nodes itself may be changed.

Example 1:

Given 1->2->3->4, reorder it to 1->4->2->3.
Example 2:

Given 1->2->3->4->5, reorder it to 1->5->2->4->3.
"""
# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

from collections import deque
class Solution:
    
    def reorderList(self, head: ListNode) -> None:
        """
        Do not return anything, modify head in-place instead.
        """
        if not head or not head.next:
            return head
        
        ptr_list = deque()
        ptr_list.append(head)
        
        while head.next!=None:
            ptr_list.append(head.next)
            head = head.next
        
        ptr = head = ptr_list.popleft()
        counter = 2
        
        while ptr_list:
            
            if counter%2==0:
                ptr.next = ptr_list.pop()
            else:
                ptr.next = ptr_list.popleft()
                
            ptr = ptr.next
            counter+=1
        
        ptr.next = None
        
        return head

# %% [markdown]
# ---

# %%
"""
Delete duplicate-value nodes from a sorted linked list.

The task is to implement the function 'removeDuplicates(head)'. 


Input: the first line denoting the number of test case, the second line is the number of elements in the linked list.
Sample input:
1
5 
1
2
2
3
4

Output to the file: 1 2 3 4

"""

#!/bin/python3

import math
import os
import random
import re
import sys

class SinglyLinkedListNode:
    def __init__(self, node_data):
        self.data = node_data
        self.next = None

class SinglyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    def insert_node(self, node_data):
        node = SinglyLinkedListNode(node_data)

        if not self.head:
            self.head = node
        else:
            self.tail.next = node


        self.tail = node

def print_singly_linked_list(node, sep, fptr):
    while node:
        fptr.write(str(node.data))

        node = node.next

        if node:
            fptr.write(sep)

# Complete the removeDuplicates function below.

#
# For your reference:
#
# SinglyLinkedListNode:
#     int data
#     SinglyLinkedListNode next

def removeDuplicates(head):

    ptr1 = head
    ptr2 = head.next

    while ptr2!=None:
        if ptr2.data==ptr1.data:
            ptr1.next = ptr2.next
            ptr2 = ptr2.next
            continue
        ptr1 = ptr1.next
        ptr2 = ptr2.next
    
    return head
         


if __name__ == '__main__':
    
    fptr = open("solution.txt", 'w')

    t = int(input())

    for t_itr in range(t):
        llist_count = int(input())

        llist = SinglyLinkedList()

        for _ in range(llist_count):
            llist_item = int(input())
            llist.insert_node(llist_item)

        llist1 = removeDuplicates(llist.head)

        print_singly_linked_list(llist1, ' ', fptr)
        fptr.write('\n')

    fptr.close()
# Out:
# 1
# 5
# 1
# 2
# 2
# 3
# 4
